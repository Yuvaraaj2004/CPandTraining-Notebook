# %%
# Import the required libraries
import matplotlib.pyplot as plt
import warnings
import seaborn as sns
import pandas as pd
pd.set_option('display.max_columns', 100)
warnings.simplefilter('ignore')

# %%
data = pd.read_csv("vehicle_data_1.csv")

# %%
print("DF Shape")
data.shape
# Out:
# DF Shape
# (100, 13)

# %%
num_cols = data.select_dtypes(exclude='object')
num_cols
# Out:
#     year  selling_price  km_driven  mileage_kmpl  engine_cc  max_power_bhp  \
# 0   2014         450000     145500         23.40     1248.0          74.00
# 1   2014         370000     120000         21.14     1498.0         103.52
# 2   2006         158000     140000         17.70     1497.0          78.00
# 3   2010         225000     127000         23.00     1396.0          90.00
# 4   2007         130000     120000         16.10     1298.0          88.20
# ..   ...            ...        ...           ...        ...            ...
# 95  2013         525000      61500         18.50     1197.0          82.85
# 96  2016         600000     150000         26.59     1248.0          74.00
# 97  2016         565000      72000         19.10     1197.0          82.00
# 98  2008         120000      68000         19.70      796.0          46.30
# 99  2017         725000     110000         22.54     1396.0          88.73
#
#     seats
# 0     5.0
# 1     5.0
# 2     5.0
# 3     5.0
# ...

# %%
def ploting(data,title,num_cols,ref,fileName,rows=3,cols=3,hs=0.5,ws=0.5,):
    fig=plt.figure(figsize=(cols*5,rows*5))
    plt.subplots_adjust(hspace=hs,wspace=ws)
    plt.suptitle(title)
    for i,col in enumerate(num_cols):
        ref(x=data[col],ax=fig.add_subplot(rows,cols,i+1))
    plt.savefig(fileName)

# %%
l=[
    {'data':data,'title':'histogram','num_cols':num_cols,'ref':sns.histplot,'fileName':'histogram.png'},
    {'data': data, 'title': 'KDE plot', 'num_cols': num_cols, 'ref': sns.kdeplot, 'fileName': 'kde.png'},
    {'data': data, 'title': 'Rug plot', 'num_cols': num_cols, 'ref': sns.rugplot, 'fileName': 'rugplot.png'},
    {'data': data, 'title': 'Box plot', 'num_cols': num_cols, 'ref': sns.boxplot, 'fileName': 'boxplot.png'},
    {'data': data, 'title': 'Violin plot', 'num_cols': num_cols, 'ref': sns.violinplot, 'fileName': 'violinplot.png'},
    {'data': data, 'title': 'Strip plot', 'num_cols': num_cols, 'ref': sns.stripplot, 'fileName': 'stripplot.png'},
    {'data': data, 'title': 'count plot', 'num_cols': data.select_dtypes(include='object'), 'ref':sns.countplot, 'fileName': 'countplot.png','rows':2,'cols':2},
    {'data': data, 'title': 'pie chart', 'num_cols': data.select_dtypes(include='object'), 'ref': plt.pie, 'fileName': 'piechart.png', 'rows': 3, 'cols': 3}]
for i in l:
    ploting(**i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 11
#       1 l=[
#       2     {'data':data,'title':'histogram','num_cols':num_cols,'ref':sns.histplot,'fileName':'histogram.png'},
#       3     {'data': data, 'title': 'KDE plot', 'num_cols': num_cols, 'ref': sns.kdeplot, 'fileName': 'kde.png'},
#    (...)
#       8     {'data': data, 'title': 'count plot', 'num_cols': data.select_dtypes(include='object'), 'ref':sns.countplot, 'fileName': 'countplot.png','rows':2,'cols':2},
#       9     {'data': data, 'title': 'pie chart', 'num_cols': data.select_dtypes(include='object'), 'ref': plt.pie, 'fileName': 'piechart.png', 'rows': 3, 'cols': 3}]
#      10 for i in l:
# ---> 11     ploting(**i)
#
# Cell In[6], line 6, in ploting(data, title, num_cols, ref, fileName, rows, cols, hs, ws)
#       4 plt.suptitle(title)
#       5 for i,col in enumerate(num_cols):
# ...

# %%
for i,col in enumerate(data.select_dtypes(include='object')):  
    (plt.pie()
    plt.legend(data)
    plt.show()

# %%
for i in col:print(data[col].value_counts().iloc[0,:])
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 for i in col:print(data[col].value_counts().iloc[0,:])
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexing.py:1652, in _iLocIndexer._getitem_tuple(self, tup)
#    1651 def _getitem_tuple(self, tup: tuple):
# -> 1652     tup = self._validate_tuple_indexer(tup)
#    1653     with suppress(IndexingError):
#    1654         return self._getitem_lowerdim(tup)
#
# ...
