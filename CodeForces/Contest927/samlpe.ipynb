# %%
import pandas as pd

# %%
df = pd.read_csv('DATASET FOR MEDICAL ASSISTANT - DISEASE_DATA.csv')
df.head()
# Out:
#             Disease  Symptom_1             Symptom_2             Symptom_3  \
# 0  Fungal infection    itching             skin_rash  nodal_skin_eruptions
# 1  Fungal infection  skin_rash  nodal_skin_eruptions   dischromic _patches
# 2  Fungal infection    itching  nodal_skin_eruptions   dischromic _patches
# 3  Fungal infection    itching             skin_rash   dischromic _patches
# 4  Fungal infection    itching             skin_rash  nodal_skin_eruptions
#
#              Symptom_4 Symptom_5 Symptom_6 Symptom_7 Symptom_8 Symptom_9  \
# 0  dischromic _patches       NaN       NaN       NaN       NaN       NaN
# 1                  NaN       NaN       NaN       NaN       NaN       NaN
# 2                  NaN       NaN       NaN       NaN       NaN       NaN
# 3                  NaN       NaN       NaN       NaN       NaN       NaN
# 4                  NaN       NaN       NaN       NaN       NaN       NaN
#
#   Symptom_10 Symptom_11 Symptom_12 Symptom_13 Symptom_14 Symptom_15  \
# ...

# %%
df = df.fillna('')
df['concat'] = df.apply(lambda row: ' '.join(row), axis=1)
df['concat']
# Out:
# 0       Fungal infection itching skin_rash nodal_skin_...
# 1       Fungal infection skin_rash nodal_skin_eruption...
# 2       Fungal infection itching nodal_skin_eruptions ...
# 3       Fungal infection itching skin_rash dischromic ...
# 4       Fungal infection itching skin_rash nodal_skin_...
#                               ...
# 4915    (vertigo) Paroymsal Positional Vertigo vomitin...
# 4916    Acne skin_rash pus_filled_pimples blackheads s...
# 4917    Urinary tract infection burning_micturition bl...
# 4918    Psoriasis skin_rash joint_pain skin_peeling si...
# 4919    Impetigo skin_rash high_fever blister red_sore...
# Name: concat, Length: 4920, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
disease = pd.DataFrame()
disease
# Out:
#                                                       0
# 0       (0, 65)\t1\n  (0, 83)\t1\n  (0, 89)\t1\n  (0...
# 1       (0, 65)\t1\n  (0, 83)\t1\n  (0, 147)\t1\n  (...
# 2       (0, 65)\t1\n  (0, 83)\t1\n  (0, 89)\t1\n  (0...
# 3       (0, 65)\t1\n  (0, 83)\t1\n  (0, 89)\t1\n  (0...
# 4       (0, 65)\t1\n  (0, 83)\t1\n  (0, 89)\t1\n  (0...
# ...                                                 ...
# 4915    (0, 180)\t1\n  (0, 108)\t1\n  (0, 68)\t1\n  ...
# 4916    (0, 147)\t1\n  (0, 4)\t1\n  (0, 132)\t1\n  (...
# 4917    (0, 83)\t1\n  (0, 27)\t1\n  (0, 173)\t1\n  (...
# 4918    (0, 147)\t1\n  (0, 91)\t1\n  (0, 130)\t1\n  ...
# 4919    (0, 147)\t1\n  (0, 73)\t1\n  (0, 80)\t1\n  (...
#
# [4920 rows x 1 columns]
