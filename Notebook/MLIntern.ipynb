# %%
import pandas as pd

# %%
df=pd.read_csv('vehicle_data.csv')
df
# Out:
#                                           name  year  selling_price  \
# 0                       Maruti Swift Dzire VDI  2014         450000
# 1                 Skoda Rapid 1.5 TDI Ambition  2014         370000
# 2                     Honda City 2017-2020 EXi  2006         158000
# 3                    Hyundai i20 Sportz Diesel  2010         225000
# 4                       Maruti Swift VXI BSIII  2007         130000
# ..                                         ...   ...            ...
# 95  Hyundai i20 Asta Optional with Sunroof 1.2  2013         525000
# 96                      Maruti Swift Dzire LDI  2016         600000
# 97        Hyundai Xcent 1.2 Kappa SX Option AT  2016         565000
# 98                        Maruti Alto LX BSIII  2008         120000
# 99                 Hyundai i20 1.4 Asta Option  2017         725000
#
#     km_driven    fuel seller_type transmission         owner     mileage  \
# 0      145500  Diesel  Individual       Manual   First Owner   23.4 kmpl
# ...

# %%
df.rename(columns={'mileage':'mileage_kmph','engine':'engine_cc','max_power':'max_power_bhp'},inplace=True)
df
# Out:
#                                           name  year  selling_price  \
# 0                       Maruti Swift Dzire VDI  2014         450000
# 1                 Skoda Rapid 1.5 TDI Ambition  2014         370000
# 2                     Honda City 2017-2020 EXi  2006         158000
# 3                    Hyundai i20 Sportz Diesel  2010         225000
# 4                       Maruti Swift VXI BSIII  2007         130000
# ..                                         ...   ...            ...
# 95  Hyundai i20 Asta Optional with Sunroof 1.2  2013         525000
# 96                      Maruti Swift Dzire LDI  2016         600000
# 97        Hyundai Xcent 1.2 Kappa SX Option AT  2016         565000
# 98                        Maruti Alto LX BSIII  2008         120000
# 99                 Hyundai i20 1.4 Asta Option  2017         725000
#
#     km_driven    fuel seller_type transmission         owner mileage_kmph  \
# 0      145500  Diesel  Individual       Manual   First Owner    23.4 kmpl
# ...

# %%
v=df['name'].str.split(n=1)
df['make'],df['model']=v.str[0],v.str[1]
df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           100 non-null    object
#  1   year           100 non-null    int64
#  2   selling_price  100 non-null    int64
#  3   km_driven      100 non-null    int64
#  4   fuel           100 non-null    object
#  5   seller_type    100 non-null    object
#  6   transmission   100 non-null    object
#  7   owner          100 non-null    object
#  8   mileage_kmph   96 non-null     object
#  9   engine_cc      96 non-null     object
#  10  max_power_bhp  96 non-null     object
#  11  torque         96 non-null     object
#  12  seats          96 non-null     float64
#  13  make           100 non-null    object
#  14  model          100 non-null    object
# dtypes: float64(1), int64(3), object(11)
# memory usage: 11.8+ KB

# %%
import re
def split(reg,data):
    return float(re.findall(reg,data))

# %%
df['mileage_kmph']=df['mileage_kmph'].str.split().str[0].astype(float)
df
# Out:
#                                           name  year  selling_price  \
# 0                       Maruti Swift Dzire VDI  2014         450000
# 1                 Skoda Rapid 1.5 TDI Ambition  2014         370000
# 2                     Honda City 2017-2020 EXi  2006         158000
# 3                    Hyundai i20 Sportz Diesel  2010         225000
# 4                       Maruti Swift VXI BSIII  2007         130000
# ..                                         ...   ...            ...
# 95  Hyundai i20 Asta Optional with Sunroof 1.2  2013         525000
# 96                      Maruti Swift Dzire LDI  2016         600000
# 97        Hyundai Xcent 1.2 Kappa SX Option AT  2016         565000
# 98                        Maruti Alto LX BSIII  2008         120000
# 99                 Hyundai i20 1.4 Asta Option  2017         725000
#
#     km_driven    fuel seller_type transmission         owner  mileage_kmph  \
# ...

# %%
df['engine_cc']=df['engine_cc'].str.split().str[0].astype(float)
df
# Out:
#                                           name  year  selling_price  \
# 0                       Maruti Swift Dzire VDI  2014         450000
# 1                 Skoda Rapid 1.5 TDI Ambition  2014         370000
# 2                     Honda City 2017-2020 EXi  2006         158000
# 3                    Hyundai i20 Sportz Diesel  2010         225000
# 4                       Maruti Swift VXI BSIII  2007         130000
# ..                                         ...   ...            ...
# 95  Hyundai i20 Asta Optional with Sunroof 1.2  2013         525000
# 96                      Maruti Swift Dzire LDI  2016         600000
# 97        Hyundai Xcent 1.2 Kappa SX Option AT  2016         565000
# 98                        Maruti Alto LX BSIII  2008         120000
# 99                 Hyundai i20 1.4 Asta Option  2017         725000
#
#     km_driven    fuel seller_type transmission         owner  mileage_kmph  \
# ...

# %%
df['max_power_bhp']=df['max_power_bhp'].str.split().str[0].astype(float)
df
# Out:
#                                           name  year  selling_price  \
# 0                       Maruti Swift Dzire VDI  2014         450000
# 1                 Skoda Rapid 1.5 TDI Ambition  2014         370000
# 2                     Honda City 2017-2020 EXi  2006         158000
# 3                    Hyundai i20 Sportz Diesel  2010         225000
# 4                       Maruti Swift VXI BSIII  2007         130000
# ..                                         ...   ...            ...
# 95  Hyundai i20 Asta Optional with Sunroof 1.2  2013         525000
# 96                      Maruti Swift Dzire LDI  2016         600000
# 97        Hyundai Xcent 1.2 Kappa SX Option AT  2016         565000
# 98                        Maruti Alto LX BSIII  2008         120000
# 99                 Hyundai i20 1.4 Asta Option  2017         725000
#
#     km_driven    fuel seller_type transmission         owner  mileage_kmph  \
# ...

# %%
# df.reindex(['make','model','year','selling_price','km_driven','fuel','seller_type','transmission','owner','mileage_kmph','engine_cc','max_power_bhp','seats'])
df[['make','model','year','selling_price','km_driven','fuel','seller_type','transmission','owner','mileage_kmph','engine_cc','max_power_bhp','seats']].to_csv('output.csv',index=False)

# %%
pd.read_csv('output.csv')
# Out:
#        make                               model  year  selling_price  \
# 0    Maruti                     Swift Dzire VDI  2014         450000
# 1     Skoda              Rapid 1.5 TDI Ambition  2014         370000
# 2     Honda                  City 2017-2020 EXi  2006         158000
# 3   Hyundai                   i20 Sportz Diesel  2010         225000
# 4    Maruti                     Swift VXI BSIII  2007         130000
# ..      ...                                 ...   ...            ...
# 95  Hyundai  i20 Asta Optional with Sunroof 1.2  2013         525000
# 96   Maruti                     Swift Dzire LDI  2016         600000
# 97  Hyundai        Xcent 1.2 Kappa SX Option AT  2016         565000
# 98   Maruti                       Alto LX BSIII  2008         120000
# 99  Hyundai                 i20 1.4 Asta Option  2017         725000
#
#     km_driven    fuel seller_type transmission         owner  mileage_kmph  \
# ...
